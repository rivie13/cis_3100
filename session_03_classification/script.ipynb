# %% [markdown]
# # Binary Classification

# %% [markdown]
# ## Create a mock dataset for binary classification
# You don't have to understand the code below. Just run it and see the result.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# Generate a synthetic dataset for binary classification
X, y = make_classification(n_samples=100, n_features=2, n_redundant=0,
                           n_informative=2, random_state=2,
                           n_clusters_per_class=2)

# Convert to DataFrame for better visualization
df = pd.DataFrame(X, columns=['Feature 1', 'Feature 2'])
df['Target'] = y

# Plot the data
plt.figure(figsize=(10, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], label='Class 0', alpha=0.5)
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label='Class 1', alpha=0.5)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Binary Classification Dataset')
plt.legend()
plt.show()



# Visualize decision boundary
def plot_decision_boundary(X, y, model):
    h = 0.02  # Step size in the mesh
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(10, 6))
    plt.contourf(xx, yy, Z, alpha=0.4)
    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.8)
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Logistic Regression Decision Boundary')
    plt.show()

# %%
X[0]
# Out:
# array([ 0.32111815, -0.95091971])

# %%
y[0]
# Out:
# np.int64(0)

# %% [markdown]
# ## Train a logistic regression model

# %%
# Create and train the logistic regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)
# Plot the decision boundary
plot_decision_boundary(X, y, model)

# Show model coefficients and intercept
print("\nModel Parameters:")
print("----------------")
print(f"Coefficients: {model.coef_[0]}")
print(f"Intercept: {model.intercept_[0]}")
# Out:
# Model Parameters:
# ----------------
# Coefficients: [0.27340426 2.01858053]
# Intercept: 0.001763000024151926

# %%
# Calculate and show probability predictions for a random sample
X_sample = np.array([[1, 1]])
res = model.predict_proba(X_sample)
print(res)
# Out:
# [[0.09164209 0.90835791]]

# %% [markdown]
# ## Decision Tree
#
# We used a linear regression, which is a particular algorithm to solve this classification problem. Another popular algorithm for classification is decision trees.
#
# Next, we will repeat the same steps for a decision tree.

# %%
# Import the decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Your turn:Create and train the decision tree model. 
# your code here

# %%
# Plot the decision boundary
plot_decision_boundary(X, y, model)

# %%
# You can actually see what is inside of the decision tree. Plot the tree
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))
plot_tree(model, filled=True, feature_names=['Feature 1', 'Feature 2'], class_names=['Class 0', 'Class 1'])
plt.show()
